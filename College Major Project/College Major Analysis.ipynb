# %% [markdown]
# # College Major Implications
#
# todo: add desciption

# %%
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib as plt

# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# Low_wage_jobs                             193
# Name: 0, dtype: object

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 168       2190                  3602         304           0.046320   26000
# 169        572                  1211         148           0.065112   25000
# 170        648                  1293         368           0.149048   25000
# 171        965                  2738         214           0.053621   23400
# 172        237                   410          87           0.104946   22000
#
#      P25th  P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 168  20000  39000          2771              2947            743
# 169  24000  34000          1488               615             82
# 170  25000  40000           986               870            622
# 171  19200  26000          2403              1245            308
# 172  20000  22000           288               338            192
#
# [5 rows x 21 columns]

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# std      0.231205   618.361022   50675.002241   42869.655092   14648.179473
# min      0.000000     2.000000       0.000000     111.000000       0.000000
# 25%      0.336026    39.000000    3608.000000    3154.000000    1030.000000
# 50%      0.534024   130.000000   11797.000000   10048.000000    3299.000000
# 75%      0.703299   338.000000   31433.000000   25147.000000    9948.000000
# max      0.968954  4212.000000  307933.000000  251540.000000  115172.000000
#
#        Full_time_year_round    Unemployed  Unemployment_rate         Median  \
# count            173.000000    173.000000         173.000000     173.000000
# mean           19694.427746   2416.329480           0.068191   40151.445087
# std            33160.941514   4112.803148           0.030331   11470.181802
# min              111.000000      0.000000           0.000000   22000.000000
# 25%             2453.000000    304.000000           0.050306   33000.000000
# 50%             7413.000000    893.000000           0.067961   36000.000000
# 75%            16891.000000   2393.000000           0.087557   45000.000000
# max           199897.000000  28169.000000           0.177226  110000.000000
#
#               P25th          P75th   College_jobs  Non_college_jobs  \
# count    173.000000     173.000000     173.000000        173.000000
# mean   29501.445087   51494.219653   12322.635838      13284.497110
# std     9166.005235   14906.279740   21299.868863      23789.655363
# min    18500.000000   22000.000000       0.000000          0.000000
# 25%    24000.000000   42000.000000    1675.000000       1591.000000
# 50%    27000.000000   47000.000000    4390.000000       4595.000000
# 75%    33000.000000   60000.000000   14444.000000      11783.000000
# max    95000.000000  125000.000000  151643.000000     148395.000000
#
#        Low_wage_jobs
# count     173.000000
# mean     3859.017341
# std      6944.998579
# min         0.000000
# 25%       340.000000
# 50%      1231.000000
# 75%      3466.000000
# max     48207.000000

# %%
# remove rows with missing data since matplotlib can't handle it

recent_data_count = len(recent_grads.index)
recent_grads = recent_grads.dropna()
cleaned_data_count = len(recent_grads.index)

print(recent_data_count)
print(cleaned_data_count)
# Out:
# 172
# 172

# %%
def get_scatter(x, y):
    recent_grads.plot(x=x, y=y, kind='scatter', title=str(x + ' vs. ' + y))

def get_hist(row, bins, x_min=0, x_max=5000):
    recent_grads[row].hist(bins=bins, range=(x_min, x_max))

# %%
get_scatter('Sample_size', 'Median')

# %%
get_scatter('Sample_size', 'Unemployment_rate')

# %%
get_scatter('Full_time', 'Median')

# %%
get_scatter('ShareWomen', 'Unemployment_rate')

# %%
get_scatter('Men', 'Median')

# %%
get_scatter('Women', 'Median')

# %% [markdown]
# ### Initial Analysis
#
# The Above scatter plots indicate that there is:
#
# - slightly positive relationship between the number of Women in a major and the Median Income
# - no coorelation between the share of women in a major and the unemployment rate
# - Men have slightly higher median incomes than women (can i concluce this from separate scatter plots)
# - A slightly negative correlation bewteen median income and full time positions aquired
# - a slightly negative correlation between the popularity of a major and the unemployment rate

# %% [markdown]
# ### Histograms

# %%
get_hist('Sample_size', 25, 0, 3000)
recent_grads['Sample_size'].describe()
# Out:
# count     172.000000
# mean      357.941860
# std       619.680419
# min         2.000000
# 25%        42.000000
# 50%       131.000000
# 75%       339.000000
# max      4212.000000
# Name: Sample_size, dtype: float64

# %%
get_hist('Median', 35, 20000, 80000)
recent_grads['Median'].describe()
# Out:
# count       172.000000
# mean      40076.744186
# std       11461.388773
# min       22000.000000
# 25%       33000.000000
# 50%       36000.000000
# 75%       45000.000000
# max      110000.000000
# Name: Median, dtype: float64

# %%
get_hist('Employed', 50, 0, 200000)

recent_grads['Employed'].describe()
# Out:
# count       172.00000
# mean      31355.80814
# std       50777.42865
# min           0.00000
# 25%        3734.75000
# 50%       12031.50000
# 75%       31701.25000
# max      307933.00000
# Name: Employed, dtype: float64

# %%
get_hist('Full_time', 50, 0, 260000)

recent_grads['Full_time'].describe()
# Out:
# count       172.000000
# mean      26165.767442
# std       42957.122320
# min         111.000000
# 25%        3181.000000
# 50%       10073.500000
# 75%       25447.250000
# max      251540.000000
# Name: Full_time, dtype: float64

# %%
get_hist('ShareWomen', 25, 0, 1)

recent_grads['ShareWomen'].describe()
# Out:
# count    172.000000
# mean       0.522223
# std        0.231205
# min        0.000000
# 25%        0.336026
# 50%        0.534024
# 75%        0.703299
# max        0.968954
# Name: ShareWomen, dtype: float64

# %%
get_hist('Unemployment_rate', 50, 0, .2)

recent_grads['Unemployment_rate'].describe()
# Out:
# count    172.000000
# mean       0.068024
# std        0.030340
# min        0.000000
# 25%        0.050261
# 50%        0.067544
# 75%        0.087247
# max        0.177226
# Name: Unemployment_rate, dtype: float64

# %%
get_hist('Men', 50, 0, 175000)

recent_grads['Men'].describe()
# Out:
# count       172.000000
# mean      16723.406977
# std       28122.433474
# min         119.000000
# 25%        2177.500000
# 50%        5434.000000
# 75%       14631.000000
# max      173809.000000
# Name: Men, dtype: float64

# %%
get_hist('Women', 50, 0, 310000)


recent_grads['Women'].describe()
# Out:
# count       172.000000
# mean      22646.674419
# std       41057.330740
# min           0.000000
# 25%        1778.250000
# 50%        8386.500000
# 75%       22553.750000
# max      307087.000000
# Name: Women, dtype: float64

# %%
get_hist('Men', 50, 0, 80000)

# %%
get_hist('Women', 50, 0, 80000)

# %% [markdown]
# ## Analysis
#
# About 33% of the sampled majors are predoninately Male and about 30% of the sampled majors are predoninately female.
#
# The most common median salarty range for new grads is $30,000 - $40,000.

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12d6defd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d70dcf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d8a60f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d987470>]],
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12cd6a7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d6b7780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cb58198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12cb40b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d11e0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12cdfb438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12d88b978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d54d2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12d54d518>]],
#       dtype=object)

# %%
recent_grads[:10]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[-10:]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen')
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[:10][["Men","Women"]].plot.bar(stacked=True)

# %%
recent_grads[["Median"]].plot.box()

# %%
recent_grads[["Men","Women","Unemployment_rate"]].plot.area(stacked=False)
